# %%
import requests

# %%
apiKey = 'ce9d991a1e37e67d2dfd5820aa08017e'
appId = '4b2af47b'
recipe_name = 'Double ka meetha'
params = {
    'q':recipe_name,
    'app_id': appId,
    'app_key': apiKey
}
response = requests.get(f'https://api.edamam.com/search', params=params)
response.status_code
# Out:
# 200

# %%
data = response.json()
from pprint import pprint

pprint(data)
# Out:
# {'count': 3,
#  'from': 0,
#  'hits': [{'recipe': {'calories': 2018.9887692335576,
#                       'cautions': ['Sulfites'],
#                       'cuisineType': ['south american'],
#                       'dietLabels': ['Balanced'],
#                       'digest': [{'daily': 129.95102129086536,
#                                   'hasRDI': True,
#                                   'label': 'Fat',
#                                   'schemaOrgTag': 'fatContent',
#                                   'sub': [{'daily': 231.58528073359375,
#                                            'hasRDI': True,
#                                            'label': 'Saturated',
#                                            'schemaOrgTag': 'saturatedFatContent',
#                                            'tag': 'FASAT',
#                                            'total': 46.317056146718755,
#                                            'unit': 'g'},
# ...

# %%
data = response.json()
from pprint import pprint

recipes = []

ingredients = data['hits'][0]['recipe']['totalNutrients']

for i in data['hits']:
    nutrients = i['recipe']['totalNutrients']
    dict = {
        'dishName' : i['recipe']['label'],
        'calories' : round(i['recipe']['calories']),
        'cuisineType' : i['recipe']['cuisineType'],
        'ingredients' : i['recipe']['ingredientLines'],
        'dishName' : i['recipe']['label'],
        'totalNutrients' : [f"{nutrients[j]['label']} : {round(nutrients[j]['quantity'], 2)}{nutrients[j]['unit']}" for j in nutrients],
        'image' : i['recipe']['image']
    }
    recipes.append(dict)
pprint(recipes)
# Out:
# [{'calories': 2019,
#   'cuisineType': ['south american'],
#   'dishName': 'Double Ka Meetha',
# ...
